# %%
# Downloads needed packages

# !pip install openai
import openai
import os
import pandas as pd
import time
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# Gets API Key
openai.api_key = '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'

# %%
# Function that calls ChatGPT
def get_completion(prompt, model="gpt-3.5-turbo"):
  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model, messages=messages, temperature=0,)
  return response.choices[0].message["content"]

# %%
# Sample prompt and response
prompt = "<What is life like in Norway?>"
response = get_completion(prompt)
print(response)
# Out:
# Life in Norway is generally considered to be of high quality. Here are some key aspects of life in Norway:
#
# 1. Standard of living: Norway consistently ranks among the top countries in terms of standard of living. The country has a strong welfare system, providing free healthcare, education, and social security benefits to its citizens.
#
# 2. Nature and outdoor activities: Norway is known for its stunning natural landscapes, including fjords, mountains, and northern lights. Norwegians have a deep appreciation for nature and outdoor activities such as hiking, skiing, fishing, and camping are popular.
#
# 3. Work-life balance: Norwegians value a healthy work-life balance. The average workweek is 37.5 hours, and employees have generous vacation time. Family and personal time are highly prioritized.
#
# 4. Education: Norway has a well-regarded education system, with free education for all citizens. The country also has several internationally recognized universities.
#
# ...

# %%
# Uploads list of countries
countries_list = pd.read_csv("/content/Countries-Continents.csv")

# %%
countries_list
# Out:
#          Continent    Country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
# Generates ChatGPT response on what is it like to live in every country
response_list = []
for i in range(len(countries_list)):
  country = countries_list.iloc[i,1]
  prompt = "<What is life like in {}?>".format(country)
  response = get_completion(prompt)
  response_list.append(response)

# %%
# Adds ChatGPT responses to dataframe
countries_list['Response'] = response_list

# %%
countries_list
# Out:
#          Continent    Country  \
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
#                                               Response
# 0    Life in Algeria is diverse and influenced by v...
# 1    Life in Angola can vary depending on various f...
# 2    Life in Benin is characterized by a rich cultu...
# 3    Life in Botswana is generally peaceful and sta...
# 4    Life in Burkina Faso, also known as Burkina, i...
# ..                                                 ...
# 189  Life in Paraguay is characterized by a mix of ...
# 190  Life in Peru is diverse and vibrant, offering ...
# 191  Life in Suriname is diverse and vibrant. The c...
# ...

# %%
from textblob import TextBlob

# %%
# Performs sentiment analysis for each country
review_polarity = []
review_subjectivity = []
for i in range(len(countries_list)):
  review = TextBlob(countries_list.iloc[i,2])
  review_polarity.append(review.sentiment[0])
  review_subjectivity.append(review.sentiment[1])

# %%
countries_list['Polarity'] = review_polarity # Polarity is how positive the sentiment is from 0 to 1
countries_list['Subjectivity'] = review_subjectivity # Subjectivity is how biased the response is from 0 to 1

# %%
countries_list
# Out:
#          Continent    Country  \
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
#                                               Response  Polarity  Subjectivity
# 0    Life in Algeria is diverse and influenced by v...  0.130639      0.428613
# 1    Life in Angola can vary depending on various f...  0.107932      0.436128
# 2    Life in Benin is characterized by a rich cultu...  0.176426      0.409097
# 3    Life in Botswana is generally peaceful and sta...  0.215936      0.516691
# 4    Life in Burkina Faso, also known as Burkina, i...  0.088784      0.423747
# ..                                                 ...       ...           ...
# ...

# %%
# Obtains 3-digit code needed to graph the world map
new = pd.read_csv('/content/all.csv')

# %%
new
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
# ...

# %%
# Takes the most important columns: the country and its 3-digit code
df = pd.DataFrame()
df['Country'] = new['name']
df['Code'] = new['alpha-3']

# %%
df
# Out:
#                Country Code
# 0          Afghanistan  AFG
# 1        Åland Islands  ALA
# 2              Albania  ALB
# 3              Algeria  DZA
# 4       American Samoa  ASM
# ..                 ...  ...
# 244  Wallis and Futuna  WLF
# 245     Western Sahara  ESH
# 246              Yemen  YEM
# 247             Zambia  ZMB
# 248           Zimbabwe  ZWE
#
# [249 rows x 2 columns]

# %%
# Left joins the country codes
df2 = pd.merge(countries_list, df, on = 'Country', how = 'left')

# %%
df2
# Out:
#          Continent    Country  \
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
#                                               Response  Polarity  \
# 0    Life in Algeria is diverse and influenced by v...  0.130639
# 1    Life in Angola can vary depending on various f...  0.107932
# 2    Life in Benin is characterized by a rich cultu...  0.176426
# 3    Life in Botswana is generally peaceful and sta...  0.215936
# 4    Life in Burkina Faso, also known as Burkina, i...  0.088784
# ..                                                 ...       ...
# 189  Life in Paraguay is characterized by a mix of ...  0.143289
# 190  Life in Peru is diverse and vibrant, offering ...  0.155121
# ...

# %%
countries_list['iso_alpha'] = df2['Code']

# %%
countries_list
# Out:
#          Continent    Country  \
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
#                                               Response  Polarity  \
# 0    Life in Algeria is diverse and influenced by v...  0.130639
# 1    Life in Angola can vary depending on various f...  0.107932
# 2    Life in Benin is characterized by a rich cultu...  0.176426
# 3    Life in Botswana is generally peaceful and sta...  0.215936
# 4    Life in Burkina Faso, also known as Burkina, i...  0.088784
# ..                                                 ...       ...
# 189  Life in Paraguay is characterized by a mix of ...  0.143289
# 190  Life in Peru is diverse and vibrant, offering ...  0.155121
# ...

# %%
# Searches missing entries
nan_rows = countries_list.isna().any(axis=1)
print(nan_rows)
filtered_countries = countries_list[nan_rows]
filtered_countries
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# Length: 194, dtype: bool
#     Continent       Country  \
# 144    Europe  Vatican City
#
#                                               Response  Polarity  \
# 144  Life in Vatican City is unique and distinct fr...  0.135276
#
#      Subjectivity iso_alpha
# 144       0.39319       NaN

# %%
# Manually adding missing entries for country names that differ between the 2 csv files
countries_list.iloc[4,5] = 'BFA'
countries_list.iloc[7,5] = 'CPV'
countries_list.iloc[12,5] = 'ZAR'
countries_list.iloc[23,5] = 'CIV'
countries_list.iloc[47,5] = 'SWZ'
countries_list.iloc[48,5] = 'TZA'
countries_list.iloc[58,5] = 'BRN'
countries_list.iloc[59,5] = 'MMR'
countries_list.iloc[62,5] = 'TMP'
countries_list.iloc[65,5] = 'IRN'
countries_list.iloc[71,5] = 'PRK'
countries_list.iloc[72,5] = 'KOR'
countries_list.iloc[75,5] = 'LAO'
countries_list.iloc[89,5] = 'SYR'
countries_list.iloc[96,5] = 'VNM'
countries_list.iloc[109,5] = 'CZE'
countries_list.iloc[125,5] = 'MKD'
countries_list.iloc[127,5] = 'MDA'
countries_list.iloc[143,5] = 'GBR'
countries_list.iloc[167,5] = 'USA'
countries_list.iloc[172,5] = 'FSM'
countries_list.iloc[183,5] = 'BOL'
countries_list.iloc[193,5] = 'VEN'

# %%
import plotly.express as px

# %%
# Create basic choropleth map
fig = px.choropleth(countries_list, locations='iso_alpha', hover_name= 'Country', color='Polarity', projection='natural earth', title='AI Sentiment Analysis by Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
